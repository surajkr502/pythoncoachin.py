# %% [markdown]
# ### How do I modify a string in python?

# %%
#concatination(+)
s='hello'
s1=s+'sir'
print(s1)
# Out:
# hellosir

# %%
#repetation(*)
s1=s*2
print(s1)
# Out:
# hellohello

# %%
# using slicing
str_='sun'
new_str='j'+str_[1:]
print(new_str)
# Out:
# jun

# %%
# type casting 
# In "" .join(lst), the empty string "" acts as a separator. 
# It joins all list elements together without adding spaces or symbols between them.
str_text='sun'
list_text=list(str_text)
# print(list_text)
list_text[0]='j'
new_str=''.join(list_text)
print(new_str)
# Out:
# jun

# %% [markdown]
# ### Write some key features of Python
# @ Key Features of Python
# 1. Easy to Learn and Use:
# Python has simple and readable syntax.
# 2. Interpreted Language:
# Python executes code line by line using an interpreter.
# 3. Object-Oriented Language:
# Python supports classes, objects, inheritance, polymorphism, etc.
# 4. Dynamically Typed:
# No need to declare variable data types explicitly.
# 5. Cross-Platform:
# Python works on Windows, Linux, and Mac.
# 6. Large Standard Library:
# Python provides many built-in modules and packages.
# 7. Open Source and Free:
# Python is freely available for everyone.
# 8. Supports Multiple Programming Paradigms:
# Supports procedural, object-oriented, and functional programming.
# 9. Large Community Support:
# Huge community for learning, troubleshooting, and development.
# 10. Extensive Frameworks and Libraries:
# Useful for AI/ML, web development, automation, data science, etc.

# %% [markdown]
# ### 12. What is the use of Floor Division in python? Explain with examples.

# %%
# rounding down the nearest integer
a=10//3
print(a)
# Out:
# 3

# %%
a=11//3
print(a)
# Out:
# 3

# %%
a=10.5//3
print(a)
# Out:
# 3.0

# %% [markdown]
# ### 14. What is the use Range function in python ?
#
# * The range() function in Python is used to generate a sequence of numbers and is mainly used with loops for iteration.
# * There are three parameter
#   a. start:(starting=0)
#   b. stop:(default=n-1)
#   c. step:(default=1)

# %%
for i in range(1,6,2): 
    print(i)
# Out:
# 1
# 3
# 5

# %% [markdown]
# ### 15. What are .py and .pyc files ?
# * A .py file is a Python source code file that contains the Python program written by the programmer.
# * A .pyc file is a compiled Python bytecode file.

# %%
# __pycache__/

# %% [markdown]
# ### 16. What are the types of literals in Python?
# * Literals in Python are constant values that are assigned to variables or used directly
# in code.
# * There are diferent types of literals like
#  * string
#  * boolean
#  * special value
#  * numeric
#  * collection of literals(list,tuple,dict,set)

# %% [raw]
# None vs empty
# None: None is a special values in python that reprents the absence of values or a null values.
# empty: Empty means data structure is exists, but there is no element contain.

# %% [markdown]
# ### 19. Write a program to print all keywords in python?
# * In Python, a keyword is a reserved word that has a special meaning in the language and cannot be used as an identifier (like a variable name, function name, etc.).

# %%
import keyword
x=keyword.kwlist
print('Total keywords=',len(x))
print('Keywords=',x)
# Out:
# Total keywords= 35
# Keywords= ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ### 20. Write a program to print punctuation in python.
# * In Python, punctuation refers to special symbols or characters used to structure and organize the code.These symbols have special meanings in Python syntax.

# %%
import string
punctuator=string.punctuation
print('Total no. of punctuator=',len(punctuator))
print('Punctuator=',punctuator)
# Out:
# Total no. of punctuator= 32
# Punctuator= !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %% [markdown]
# ### 21. What is a token in python?
# In Python, a token is the smallest unit of the source code that the Python
# interpreter recognizes during the process of lexical analysis (the first step in code
# compilation or interpretation). Each token represents a meaningful element in
# Python, such as
# 1. Keywords.
# 2. Punctuation/delimiters.
# 3. Identifiers.
# 4. Operators.
# 5. Literals

# %% [markdown]
# ### inbuilt fn vs inbuilt method in python?
# Inbuilt functions are predefined functions provided by Python that can be used directly, while inbuilt methods are functions associated with specific objects or datatypes and are called using the dot operator.

# %% [markdown]
# ### 24. What is the list in python? Explain list methods with examples.
#  We use a list in Python when we want to store multiple objects together in an ordered and mutable collection that also allows duplicate values.
# * Whenever we want to create a group of objects where we want below mention
# properties, then we are using list sequence.
# 1. Duplicates are allowed.
# 2. Order is preserved.
# 3. Objects are mutable.
# 4. Indexing are allowed.
# 5. Slicing are allowed.
# 6. Represented in square bracket with comma separated objects.
# 7. Homogeneous and Heterogeneous both objects are allowed.

# %%
#Different memory address so, list is mutable object.
list_1=['suraj','sun']
list_2=['rohan','shohan']
print(id(list_1),id(list_2))
# Out:
# 1867298628928 1867298634176

# %%
# Duplicates are allow 
list_1=['ram',40,29,13,{'age':40},35] #homogeneous and heterogeneous both objects are allow
print(list_1)
# Out:
# ['ram', 40, 29, 13, {'age': 40}, 35]

# %%
# Order preserved 
list_1=['ram',40,29,13,{'age':40},35]
x=0
for i in list_1: 
    print('list_1[{}]='.format(x),i)
    x=x+1
# Out:
# list_1[0]= ram
# list_1[1]= 40
# list_1[2]= 29
# list_1[3]= 13
# list_1[4]= {'age': 40}
# list_1[5]= 35

# %% [markdown]
# * In Python, .format() is used to insert values into a string dynamically.
#
# * It is a string formatting method.

# %%
# Example
demo=[43,27,445,765,'age','name',78]
x=0
for i in demo: 
    print('insert[{}]'.format(x),i)
    x=x+1
# Out:
# insert[0] 43
# insert[1] 27
# insert[2] 445
# insert[3] 765
# insert[4] age
# insert[5] name
# insert[6] 78

# %%
# Object are mutable 
list_1=[43,64,'sun',79]
x=0
for i in list_1: 
    print('index[{}]'.format(x),i) 
    x=x+1
list_1[0]='ram'
print(list_1)
# Out:
# index[0] 43
# index[1] 64
# index[2] sun
# index[3] 79
# ['ram', 64, 'sun', 79]

# %%
# Indexing
lis=[12,34,5,64,'python',53,'java']
print(lis[2])
# Out:
# 5

# %%
# Slicing 
lis=[12,34,5,64,'python',53,'java']
print(lis[:])
print(lis[1::])
# Out:
# [12, 34, 5, 64, 'python', 53, 'java']
# [34, 5, 64, 'python', 53, 'java']

# %% [markdown]
# ### Inbuilt functions in list:
# * len(list)
# * max(list) - homogeneous collection required
# * min(list) - homogeneous collection required
# * sum(list) - integer homogeneous collection required
# * list(tuple)
# * type(list)
# * id()
# * list()

# %% [markdown]
# ### Method In list

# %%
# append 
lst=[12,45,64,24,'java']
lst.append('python')
print(lst)
# Out:
# [12, 45, 64, 24, 'java', 'python']

# %%
# append 
lst=[12,45,64,24,'java']
lst2=['python','cpp','c']
lst.append(lst2)
print(lst)
# Out:
# [12, 45, 64, 24, 'java', ['python', 'cpp', 'c']]

# %%
# count 
lst=[2,42,2,52,55,2]
print(lst.count(2))
# Out:
# 3

# %%
# extend 
lst=[12,45,64,24,'java']
lst_2=['python','java scripts']
print(lst.extend(lst_2))
# Out:
# None

# %%
# extend 
lst=[12,45,64,24,'java']
lst_2=['python','java scripts']
lst.extend(lst_2)
print(lst)
# Out:
# [12, 45, 64, 24, 'java', 'python', 'java scripts']

# %%
# insert 
# list.insert(index,obj) – insert given object in given index.
lst=[12,45,64,24,'java']
lst_2=['python','java scripts']
lst.insert(2,lst_2)
print(lst)
# Out:
# [12, 45, ['python', 'java scripts'], 64, 24, 'java']

# %%
# list.pop() – delete bydefault last object from given list. 
lst=[12,45,64,24,'java']
lst.pop() #give index
print(lst)
# Out:
# [12, 45, 64, 24]

# %%
# list.remove(obj) – Remove given object from given list. 
lst=[12,45,64,24,'java']
lst.remove('java')
print(lst)
# Out:
# [12, 45, 64, 24]

# %%
# list.reverse()
lst=[12,45,64,24,'java']
lst.reverse()
print(lst)
# Out:
# ['java', 24, 64, 45, 12]

# %%
# list.sort(reverse=True/False) default-False 
lst=[12,45,64,24]
lst.sort(reverse=True)
print(lst)
# Out:
# [64, 45, 24, 12]

# %% [markdown]
# ## Function revision questions

# %%
def reverse(text):
    return text[::-1]

print(reverse("Python"))
# Out:
# nohtyP

# %%
def factorial(n):
    fact = 1

    for i in range(1, n + 1):
        fact = fact * i

    return fact

print(factorial(5))
# Out:
# 120

# %%
def prime(n):
    if n <= 1:
        return "Not Prime"

    for i in range(2, n):
        if n % i == 0:
            return "Not Prime"

    return "Prime"

print(prime(7))
# Out:
# Prime

# %%
square = lambda x: x * x

print(square(5))
# Out:
# 25

# %% [markdown]
# ### 25. What is the tuple in python? Explain methods with examples.
# In Python, tuples are immutables. Meaning, you cannot change items of a tuple once
# it is assigned. There are only two tuple methods count() and index() that a tuple
# object can call.
# * Built-in functions:-
# 1. Len(tuple) # tuple variable must be a iterable.
# 2. Max(tuple)
# 3. Min(tuple)
# 4. Sum(tuple)
# 5. Tuple(list)
# 6. Type(tuple)

# %% [markdown]
# ## 26. What is the dictionary in python? Explain methods with examples.
# * I we want to represent the group of object in key value pair then we use dictionary.
# ### Characteristics of Dictionary
# 1. Dictionary will contain data in the form of key, value pairs.
# 2. Key and values are separated by a colon “:” symbol
# 3. One key-value pair can be represented as an item.
# 4. Duplicate keys are not allowed.
# 5. Duplicate values can be allowed.
# 6. Heterogeneous objects are allowed for both keys and values.
# 7. Insertion order is not preserved.
# 8. Dictionary object having mutable nature.
# 9. Dictionary objects are dynamic.
# 10. Indexing and slicing concepts are not applicable

# %%
# creating empty dictionary 
d={}
print(type(d))
# Out:
# <class 'dict'>

# %%
# insertion key and object in empty dictionary 
d={}
d[1]='suraj'
d[2]='mohan'
d[3]='rohan'
print(d)
# Out:
# {1: 'suraj', 2: 'mohan', 3: 'rohan'}

# %%
# Accessing dictionary's value by using key. 
print(d[1])
print(d[2])
print(d[3])
print(d[10])
# Out:
# suraj
# mohan
# rohan
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 5
#       3 print(d[2])
#       4 print(d[3])
# ----> 5 print(d[10])
#
# KeyError: 10

# %%
key=int(input('Entered key:'))
if key in d:
    print('value of given key is:',d[key]) 
else: 
    print('Key not found')
# Out:
# Entered key: 1
# value of given key is: suraj

# %%
# Getting employee's information in the form of dictionaries.
d={}
n=int(input('Enter total no. of employees'))
i=1
while i <=n: 
    name=input('Enter employee name')
    salary=int(input('Enter employee salary'))
    d[name]=salary
    i=i+1
print(d)
# Out:
# Enter total no. of employees 2
# Enter employee name sun
# Enter employee salary 5667
# Enter employee name sun
# Enter employee salary 7899
# {'sun': 7899}

# %% [markdown]
# ### Updating dictionary elements:
# * We can update the value for a particular key in a dictionary. The syntax is:
# * d[key] = value

# %%
# Case1: While updating the key in the dictionary, if the key is not available then a 
# new key will be added at the end of the dictionary with the specified value. 
d={1:'suraj',2:'saroj',3:'ganesh'}
print('old dict:',d)
d[4]='chandani'
print('new dict:',d)
# Out:
# old dict: {1: 'suraj', 2: 'saroj', 3: 'ganesh'}
# new dict: {1: 'suraj', 2: 'saroj', 3: 'ganesh', 4: 'chandani'}

# %%
#Case2: If the key already exists in the dictionary, then the old value will be replaced
#with a new value.
d={1:'rohan',2:'sohan'}
print('old dict:',d)
d[2]='arvind'
print('new dict:',d)
# Out:
# old dict: {1: 'rohan', 2: 'sohan'}
# new dict: {1: 'rohan', 2: 'arvind'}

# %% [markdown]
# ### Removing or deleting elements from the dictionary:
# 1. By using the del keyword, we can remove the keys
# 2. By using clear() we can clear the objects in the dictionary

# %%
#By using the del keyword
#Syntax: del d[key]
d={1:'sun',2:'moon'}
print('old dict:',d)
del d[2]
print('new dict:',d)
# Out:
# old dict: {1: 'sun', 2: 'moon'}
# new dict: {1: 'sun'}

# %%
# By using clear() keyword 
# syntax: d.clear()
# clear() method: This method can remove all elements from the dictionary. 

d={1:'earth',2:'jupyter'}
print('old dict:',d)
d.clear()
print('new dict:',d)
# Out:
# old dict: {1: 'earth', 2: 'jupyter'}
# new dict: {}

# %% [markdown]
# ### Delete entire dictionary object:-
# We can also use the del keyword to delete the total
# dictionary object. Before deleting we just have to note that once it is deleted then we
# cannot access the dictionary.

# %%
d={1:'person',2:'animal','bird':3}
print('new dict:',d)
del d
print('old dict:',d)
# Out:
# new dict: {1: 'person', 2: 'animal', 'bird': 3}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2 print('new dict:',d)
#       3 del d
# ----> 4 print('old dict:',d)
#
# NameError: name 'd' is not defined

# %% [markdown]
# ### Functions of dictionary in Python
# 1. dict()
# 2. len() – total object length
# 3. max() – on the basis of key
# 4. min() – on the basis of key
# 5. id()
# 6. type()

# %% [markdown]
# ### dict() function:
# * This can be used to create an empty dictionary.

# %%
empty_dict=dict()  #to create empty dictionary
print(empty_dict)
# Out:
# {}

# %%
# A list containing pairs of data
data_pairs = [("apple", 3), ("banana", 5), ("cherry", 2)]

fruits = dict(data_pairs)
print(fruits)
# Out:
# {'apple': 3, 'banana': 5, 'cherry': 2}

# %%
d={1:'sun',2:'moon'}
dict(d)
# Out:
# {1: 'sun', 2: 'moon'}

# %%
# len() function: This function returns the number of items in the dictionary. 
len(d)
# Out:
# 2

# %%
max(d)
# Out:
# 2

# %%
min(d)
# Out:
# 1

# %%
id(d)
# Out:
# 2808849760320

# %%
type(d)
# Out:
# dict

# %% [markdown]
# ### Methods of dictionary in Python

# %%
# 1. setdefault() 
d={1:'suraj',2:'saroj',4:'ganesh'}
d.setdefault(3,'chandni')
print(d)
# Since 3 is not in d, setdefault adds 3: 'chandni' to the dictionary.
# If 3 were already a key in the dictionary, setdefault would leave it
#unchanged and just return the existing value.
# Out:
# {1: 'suraj', 2: 'saroj', 4: 'ganesh', 3: 'chandni'}

# %%
# 2. fromkeys() # dict.fromkeys(keys, value) Initializing multiple keys with the same value.
keys=['a','b','c','d']
new_dict=dict.fromkeys(keys,0)
print(new_dict)
# Out:
# {'a': 0, 'b': 0, 'c': 0, 'd': 0}

# %%
#4. update() 
# x.update(collection) Updating a dictionary with another dictionary 
dict1={1:'a',2:'b',1:'c'}
dict2={2:'c',4:'d',3:'c'}
dict1.update(dict2)
print(dict1)
# Out:
# {1: 'c', 2: 'c', 4: 'd', 3: 'c'}

# %% [markdown]
# 5. copy() # x.copy()
# 6. get() # x.get(‘key’)
# 7. clear() # x.clear()
# 8. pop() # x.pop(‘key’)
# 9. popitem() # x.popitem()
# 10. key() # x.keys()
# 11. values() # x.values()
# 12. items() # x.items()

# %% [markdown]
# ### get() method:
# """ This method used to get the value associated with the key. This is another way to get
# the values of the dictionary based on the key. The biggest advantage it gives over the
# normal way of accessing a dictionary is, this doesn’t give any error if the key is not
# present. Let’s see through some examples:"""

# %%
''' Case1: If the key is available, then it returns the corresponding value otherwise
returns None. It won’t raise any errors.
Syntax: d.get(key)''' 
d={1:'sun',2:'moon',3:'earth'}
print(d.get(1))
print(d.get(4))
print(d.get(3))
# Out:
# sun
# None
# earth

# %%
'''Case 2: If the key is available, then returns the corresponding value otherwise returns
the default value that we give.
Syntax: d.get(key, defaultvalue)'''

# %%
d={1:'suraj',3:'chandni',4:'ganesh'}
print(d.get(2,'saroj'))
print(d.get(4,'None'))
# Out:
# saroj
# ganesh

# %% [markdown]
# ### pop() method:
# """This method removes the entry associated with the specified key and
# returns the corresponding value. If the specified key is not available, then we will get
# KeyError.
# Syntax: d.pop(key)
# """

# %%
d={1:'suraj',3:'chandni',4:'ganesh'}
d.pop(3)
print(d)
# Out:
# {1: 'suraj', 4: 'ganesh'}

# %%
d.pop(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 d.pop(3)
#
# KeyError: 3

# %% [markdown]
# ### popitem() method:
# This method removes an arbitrary item(key-value) from the
# dictionary and returns it.

# %%
d={1: 'Neeraj', 2: 'Rahul', 3: 'Ravi',4:'Jai',5:'Santosh'}
print(d.popitem())
print(d)
# Out:
# (5, 'Santosh')
# {1: 'Neeraj', 2: 'Rahul', 3: 'Ravi', 4: 'Jai'}

# %% [markdown]
# ### keys() method:
# This method returns all keys associated with the dictionary

# %%
d={1: 'Neeraj', 2: 'Rahul', 3: 'Ravi',4:'Jai',5:'Santosh'}
print(d.keys())
# Out:
# dict_keys([1, 2, 3, 4, 5])

# %% [markdown]
# ### values() method:
# This method returns all values associated with the dictionary

# %%
d={1: 'Neeraj', 2: 'Rahul', 3: 'Ravi',4:'Jai',5:'Santosh'}
print(d.values())
# Out:
# dict_values(['Neeraj', 'Rahul', 'Ravi', 'Jai', 'Santosh'])

# %% [markdown]
# ### items() method:
# A key-value pair in a dictionary is called an item. items() method
# returns the list of tuples representing key-value pairs.

# %%
d={1: 'Neeraj', 2: 'Rahul', 3: 'Ravi',4:'Jai',5:'Santosh'}
for k,v in d.items(): 
    # print(k,"---",v)
    print(k,v)
# Out:
# 1 Neeraj
# 2 Rahul
# 3 Ravi
# 4 Jai
# 5 Santosh

# %%
dict2={2:'c',4:'d',3:'c'}
dict1=dict()
dict2.copy()
print(dict2)
# Out:
# {2: 'c', 4: 'd', 3: 'c'}

# %% [markdown]
# ## 27. What is the set in python? Explain methods with examples.
# If we want to represent a group of unique elements then we can go for sets. Set
# cannot store duplicate elements.
# 1. Duplicates are not allowed.
# 2. Order is not preserved.
# 3. Objects are mutable.
# 4. Indexing is not allowed.
# 5. Slicing is not allowed.
# 6. Represented in { } with comma separated objects.
# 7. Homogeneous and Heterogeneous both objects are allowed.

# %%
# Creating set 
s={12,'sun',34,'moon',True,54.544}
s1={12,'sun',34,'moon',True,54.544}
print(s)
print(id(s),id(s1))
# Out:
# {True, 34, 'moon', 'sun', 54.544, 12}
# 2311606426464 2311609623584

# %%
# Create set using range 
s=set(range(1,6))
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
# Create set using range 
set_={}
for i in range(1,5+1): 
    set_.append(i)
print(s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       2 s={}
#       3 for i in range(1,5+1):
# ----> 4     s.append(i)
#       5 print(s)
#
# AttributeError: 'dict' object has no attribute 'append'

# %% [markdown]
# ### Methods in set:----

# %%
# 1. add(only_one_argument not iterable) 
s={12,'sun',45.4}
s.add(45) 
print(s)
# Out:
# {45, 12, 45.4, 'sun'}

# %%
# 2. update(iterable_obj1,iterable_obj2) 
s={'suraj',43,'moon',55.33}
s1=[54,32,55,44,66,54]
s.update(s1)
print(s)
# Out:
# {32, 66, 'moon', 43, 44, 'suraj', 55, 54, 55.33}

# %%
# 2. update(iterable_obj1,iterable_obj2) 
s={'suraj',43,'moon',55.33}
s1=[54,32,55,44,66,54]
s.update(s1,range(4))
print(s)
# Out:
# {32, 0, 66, 1, 2, 'moon', 3, 43, 44, 'suraj', 55, 54, 55.33}

# %% [markdown]
# ### Difference between add() and update() methods in set:
# 3. We can use add() to add individual items to the set, whereas we can use
# update() method to add multiple items to the set.
# 4. The add() method can take one argument whereas the update() method can take
# any number of arguments but the only point is all of them should be iterable
# objects.

# %%
def fun(x=[]):
    x.append(1)
    print(x)

fun()
fun()
fun()
# Out:
# [1]
# [1, 1]
# [1, 1, 1]

# %%
def outer():
    x = 10

    def inner():
        print(x)

    inner()

outer()
# Out:
# 10

# %%
def test(a, b=5, c=10):
    print(a, b, c)

test(3, c=20)
# Out:
# 3 5 20

# %%
def maximum(a, b):
    if a > b:
        return a
    return b

print(maximum(10, 20))
# Out:
# 20

# %%
def check(num):
    if num % 2 == 0:
        return "Even"
    return "Odd"

print(check(7))
# Out:
# Odd

# %%
def count_vowels(text):
    count = 0

    for i in text.lower():
        if i in "aeiou":
            count += 1

    return count

print(count_vowels("Python"))
# Out:
# 1

# %%
def reverse_string(text):
    return text[::-1]

print(reverse_string("Machine"))
# Out:
# enihcaM

# %%
def prime(num):

    if num <= 1:
        return "Not Prime"

    for i in range(2, num):
        if num % i == 0:
            return "Not Prime"

    return "Prime"

print(prime(7))
# Out:
# Prime

# %%
def display(n):

    if n == 0:
        return

    display(n - 1)
    print(n)

display(5)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def average(*numbers):
    return sum(numbers) / len(numbers)

print(average(10, 20, 30, 40))
# Out:
# 25.0

# %%
def palindrome(text):

    if text == text[::-1]:
        return "Palindrome"

    return "Not Palindrome"

print(palindrome("madam"))
# Out:
# Palindrome

# %%
def upper_count(text):

    count = 0

    for i in text:
        if i.isupper():
            count += 1

    return count

print(upper_count("PyTHon"))
# Out:
# 3

# %%
def table(n):

    for i in range(1, 11):
        print(n, "x", i, "=", n * i)

table(5)
# Out:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
def common(a, b):

    result = []

    for i in a:
        if i in b:
            result.append(i)

    return result

print(common([1, 2, 3], [2, 3, 4]))
# Out:
# [2, 3]

# %%
def digit_sum(num):

    total = 0

    for i in str(num):
        total += int(i)

    return total

print(digit_sum(1234))
# Out:
# 10

# %%
def armstrong(num):

    total = 0
    power = len(str(num))

    for i in str(num):
        total += int(i) ** power

    if total == num:
        return "Armstrong Number"

    return "Not Armstrong Number"

print(armstrong(153))
# Out:
# Armstrong Number

# %%
balance = 1000


def check_balance():
    print("Current Balance:", balance)


def deposit(amount):

    global balance

    balance += amount

    print("Amount Deposited Successfully")


def withdraw(amount):

    global balance

    if amount > balance:
        print("Insufficient Balance")

    else:
        balance -= amount
        print("Withdrawal Successful")


while True:

    print("\n1. Check Balance")
    print("2. Deposit")
    print("3. Withdraw")
    print("4. Exit")

    choice = int(input("Enter choice: "))

    if choice == 1:
        check_balance()

    elif choice == 2:
        amount = int(input("Enter deposit amount: "))
        deposit(amount)

    elif choice == 3:
        amount = int(input("Enter withdraw amount: "))
        withdraw(amount)

    elif choice == 4:
        print("Thank You")
        break

    else:
        print("Invalid Choice")

# %%
def calculate_total(marks):
    total = sum(marks)
    return total


def calculate_percentage(total, subjects):
    percentage = total / subjects
    return percentage


def calculate_grade(percentage):

    if percentage >= 90:
        return "A"

    elif percentage >= 75:
        return "B"

    elif percentage >= 50:
        return "C"

    return "Fail"


def student_result():

    marks = []

    n = int(input("Enter number of subjects: "))

    for i in range(n):
        mark = int(input(f"Enter marks of subject {i+1}: "))
        marks.append(mark)

    total = calculate_total(marks)

    percentage = calculate_percentage(total, n)

    grade = calculate_grade(percentage)

    print("\n----- RESULT -----")
    print("Total:", total)
    print("Percentage:", percentage)
    print("Grade:", grade)


student_result()
