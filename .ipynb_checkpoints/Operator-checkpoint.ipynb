# %% [markdown]
# # Operator

# %% [markdown]
# ## 1.Arithematics:-(+,-,*,/,//(Flor),%(Modulas),**)

# %%
x=10
y=5
z=x/y
print(z,type(z))
z=x+y 
print(z,type(z))
# Out:
# 2.0 <class 'float'>
# 15 <class 'int'>

# %% [markdown]
# ## 2.Assigment:-(=)

# %%
print(x='python')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(x='python')
#
# TypeError: print() got an unexpected keyword argument 'x'

# %%
print(x:='python') # there (:) is called walrus operator-[return value]
# Out:
# python

# %%
# 3.Comparision Operator (Return boolean expression):-return boolean and values

# %%
x=10
y=20
print(x==y)
# Out:
# False

# %% [markdown]
# ## 4.Logical Operator (and,or not)

# %%
x=10
y=20
print(x and y)
# Out:
# 20

# %%
x=10
y=20
z=30
print(x and y)
# Out:
# 20

# %%
print(x>y) and (y>z)
# Out:
# False

# %%
# 5.Identity Operator

# %%
x=10
y=20
print(x is y) #(compair on the basis of memory address)
print(x==y)   #compair on the basis of value
# Out:
# False
# False

# %%
x=[1,2,3]
y=[1,2,3]
print(x is y)
print(x==y)
# print(x is not y)
# Out:
# False
# True

# %% [markdown]
# ## 6.Membership(in,not in) :-
# * requirement-> collection(string,list,tuple,dict,set,frozenset)

# %%
s='This is python class' 
print('x' in s)
print('x' not in s)
print('th' in s)
print('ht' in s)
# Out:
# False
# True
# True
# False
